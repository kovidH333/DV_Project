# %% [markdown]
# # **PREPROCESSING**

# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv("nba2k-full.csv")
data
# Out:
#                  full_name  rating jersey                   team position  \
# 0             LeBron James      97    #23     Los Angeles Lakers        F
# 1            Kawhi Leonard      97     #2   Los Angeles Clippers        F
# 2    Giannis Antetokounmpo      96    #34        Milwaukee Bucks      F-G
# 3             Kevin Durant      96     #7          Brooklyn Nets        F
# 4             James Harden      96    #13        Houston Rockets        G
# ..                     ...     ...    ...                    ...      ...
# 459             Chris Paul      88     #3  Oklahoma City Thunder        G
# 460           Bradley Beal      88     #3     Washington Wizards        G
# 461            Rudy Gobert      87    #27              Utah Jazz        C
# 462             Kyle Lowry      87     #7        Toronto Raptors        G
# 463     Kristaps Porzingis      87     #6       Dallas Mavericks      F-C
#
#         b_day       height                weight     salary country  \
# ...

# %%
data['jersey'] = data['jersey'].str.replace('#', '').astype(int)
data['jersey']
# Out:
# 0      23
# 1       2
# 2      34
# 3       7
# 4      13
#        ..
# 459     3
# 460     3
# 461    27
# 462     7
# 463     6
# Name: jersey, Length: 464, dtype: int32

# %%
data['salary'] = data['salary'].str.replace('$', '').astype(int)
data['salary']
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_20764\2984654512.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['salary'] = data['salary'].str.replace('$', '').astype(int)
# 0      37436858
# 1      32742000
# 2      25842697
# 3      37199000
# 4      38199000
#          ...
# 459    41358814
# 460    28751774
# 461    27525281
# 462    30500000
# 463    29467800
# Name: salary, Length: 464, dtype: int32

# %%
data['height'] = data['height'].str.split('/').str[1].astype(float)
data['height']
# Out:
# 0      2.06
# 1      2.01
# 2      2.11
# 3      2.08
# 4      1.96
#        ...
# 459    1.85
# 460    1.91
# 461    2.16
# 462    1.83
# 463    2.21
# Name: height, Length: 464, dtype: float64

# %%
data['weight'] = data['weight'].str.split('/').str[1]
data['weight']
# Out:
# 0       113.4 kg.
# 1       102.1 kg.
# 2       109.8 kg.
# 3       104.3 kg.
# 4        99.8 kg.
#           ...
# 459      79.4 kg.
# 460      93.9 kg.
# 461       108 kg.
# 462        93 kg.
# 463      99.8 kg.
# Name: weight, Length: 464, dtype: object

# %%
data['weight'] = data['weight'].str.replace('kg.','').astype(float)
data['weight']
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_20764\1060521108.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['weight'] = data['weight'].str.replace('kg.','').astype(float)
# 0      113.4
# 1      102.1
# 2      109.8
# 3      104.3
# 4       99.8
#        ...
# 459     79.4
# 460     93.9
# 461    108.0
# 462     93.0
# 463     99.8
# Name: weight, Length: 464, dtype: float64

# %%
import datetime

def calculate_age(birth_date):
    birth_date_obj = datetime.datetime.strptime(birth_date, '%m/%d/%y')
    
    current_date = datetime.date.today()
    
    age = current_date.year - birth_date_obj.year - ((current_date.month, current_date.day) < (birth_date_obj.month, birth_date_obj.day))
    
    return age

# %%
data['age'] = data['b_day'].apply(calculate_age)
data['age']
# Out:
# 0      39
# 1      32
# 2      29
# 3      35
# 4      34
#        ..
# 459    38
# 460    30
# 461    31
# 462    38
# 463    28
# Name: age, Length: 464, dtype: int64

# %%
data
# Out:
#                  full_name  rating  jersey                   team position  \
# 0             LeBron James      97      23     Los Angeles Lakers        F
# 1            Kawhi Leonard      97       2   Los Angeles Clippers        F
# 2    Giannis Antetokounmpo      96      34        Milwaukee Bucks      F-G
# 3             Kevin Durant      96       7          Brooklyn Nets        F
# 4             James Harden      96      13        Houston Rockets        G
# ..                     ...     ...     ...                    ...      ...
# 459             Chris Paul      88       3  Oklahoma City Thunder        G
# 460           Bradley Beal      88       3     Washington Wizards        G
# 461            Rudy Gobert      87      27              Utah Jazz        C
# 462             Kyle Lowry      87       7        Toronto Raptors        G
# 463     Kristaps Porzingis      87       6       Dallas Mavericks      F-C
#
# ...

# %%
data.to_csv("data.csv", index=False)

# %%
data['BMI'] = data['weight'] / (data['height'] ** 2)
data['BMI']
# Out:
# 0      26.722594
# 1      25.271652
# 2      24.662519
# 3      24.107803
# 4      25.978759
#          ...
# 459    23.199416
# 460    25.739426
# 461    23.148148
# 462    27.770313
# 463    20.433652
# Name: BMI, Length: 464, dtype: float64

# %%
data.to_csv("data.csv", index=False)
